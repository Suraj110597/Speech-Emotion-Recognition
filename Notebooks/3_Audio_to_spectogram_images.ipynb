# %% [markdown]
# <a href="https://colab.research.google.com/github/sagarrokad1/Speech-Emotion-Recognition/blob/main/Notebooks/3_Audio_to_spectogram_images.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **Importing Libraries**

# %%
# IMPORT NECESSARY LIBRARIES
import librosa
import librosa.display

import os, glob, sys

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.pyplot import specgram
# %matplotlib inline

from sklearn.model_selection import train_test_split

import warnings
if not sys.warnoptions:
    warnings.simplefilter("ignore")
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
#mounting the google drive to import the dataset

from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %% [markdown]
# ###**Reading Audio File**

# %%
audio = "/content/drive/MyDrive/AlmaBetter/Capstone Projects/Speech Emotion Recognition - Sagar Rokad/Audio_data/"

# %%
audio_df=pd.read_csv('/content/drive/MyDrive/AlmaBetter/Capstone Projects/Speech Emotion Recognition - Sagar Rokad/audio.csv')

# %%
audio_df.head()
# Out:
#    Unnamed: 0 gender  ... actor                                               path
# 0           0   male  ...     1  /content/drive/MyDrive/AlmaBetter/Capstone Pro...
# 1           1   male  ...     1  /content/drive/MyDrive/AlmaBetter/Capstone Pro...
# 2           2   male  ...     1  /content/drive/MyDrive/AlmaBetter/Capstone Pro...
# 3           3   male  ...     1  /content/drive/MyDrive/AlmaBetter/Capstone Pro...
# 4           4   male  ...     1  /content/drive/MyDrive/AlmaBetter/Capstone Pro...
#
# [5 rows x 5 columns]

# %%
audio_df=audio_df.drop('Unnamed: 0',axis=1)

# %%
audio_df.head()
# Out:
#   gender  emotion  actor                                               path
# 0   male  neutral      1  /content/drive/MyDrive/AlmaBetter/Capstone Pro...
# 1   male  neutral      1  /content/drive/MyDrive/AlmaBetter/Capstone Pro...
# 2   male     calm      1  /content/drive/MyDrive/AlmaBetter/Capstone Pro...
# 3   male  neutral      1  /content/drive/MyDrive/AlmaBetter/Capstone Pro...
# 4   male     calm      1  /content/drive/MyDrive/AlmaBetter/Capstone Pro...

# %%
# TRAIN TEST SPLIT DATA
train,test = train_test_split(audio_df, test_size=0.2, random_state=0,
                               stratify=audio_df[['emotion','gender','actor']])

# %%
#top 5 rows
test.head()
# Out:
#       gender emotion  actor                                               path
# 226   female    fear      4  /content/drive/MyDrive/AlmaBetter/Capstone Pro...
# 1253    male    calm     21  /content/drive/MyDrive/AlmaBetter/Capstone Pro...
# 924   female   happy     16  /content/drive/MyDrive/AlmaBetter/Capstone Pro...
# 708   female   angry     12  /content/drive/MyDrive/AlmaBetter/Capstone Pro...
# 1350    male    fear     23  /content/drive/MyDrive/AlmaBetter/Capstone Pro...

# %%
# top 5 rows
train.head()
# Out:
#       gender  ...                                               path
# 690   female  ...  /content/drive/MyDrive/AlmaBetter/Capstone Pro...
# 468   female  ...  /content/drive/MyDrive/AlmaBetter/Capstone Pro...
# 1311  female  ...  /content/drive/MyDrive/AlmaBetter/Capstone Pro...
# 1438  female  ...  /content/drive/MyDrive/AlmaBetter/Capstone Pro...
# 896     male  ...  /content/drive/MyDrive/AlmaBetter/Capstone Pro...
#
# [5 rows x 4 columns]

# %%
len(train[train['emotion']=='neutral'])
# Out:
# 72

# %%
len(test[test['emotion']=='neutral'])
# Out:
# 24

# %% [markdown]
# ### **Making Train_logmel folder**
#
# **Converting training audio files to spectogram images and storing it in drive**

# %%
counter=0
for index,path in enumerate(train.path):
  if train.iloc[counter,1]=='angry':
    x, sr = librosa.load(path)
    x = librosa.feature.melspectrogram(y=x, sr=sr,n_mels=128,fmax=8000)
    y = librosa.power_to_db(x)
    librosa.display.specshow(y, y_axis='mel', fmax=8000, x_axis='time')
    plt.savefig(f'/content/drive/MyDrive/AlmaBetter/Capstone Projects/Speech Emotion Recognition - Sagar Rokad/train_logmel/angry/{counter}.png')
  counter=counter+1

# %%
counter=0
for index,path in enumerate(train.path):
  if train.iloc[counter,1]=='calm':
    x, sr = librosa.load(path)
    x = librosa.feature.melspectrogram(y=x, sr=sr,n_mels=128,fmax=8000)
    y = librosa.power_to_db(x)
    librosa.display.specshow(y, y_axis='mel', fmax=8000, x_axis='time')
    plt.savefig(f'/content/drive/MyDrive/AlmaBetter/Capstone Projects/Speech Emotion Recognition - Sagar Rokad/train_logmel/calm/{counter}.png')
  counter=counter+1

# %%
counter=0
for index,path in enumerate(train.path):
  if train.iloc[counter,1]=='disgust':
    x, sr = librosa.load(path)
    x = librosa.feature.melspectrogram(y=x, sr=sr,n_mels=128,fmax=8000)
    y = librosa.power_to_db(x)
    librosa.display.specshow(y, y_axis='mel', fmax=8000, x_axis='time')
    plt.savefig(f'/content/drive/MyDrive/AlmaBetter/Capstone Projects/Speech Emotion Recognition - Sagar Rokad/train_logmel/disgust/{counter}.png')
  counter=counter+1

# %%
counter=0
for index,path in enumerate(train.path):
  if train.iloc[counter,1]=='fear':
    x, sr = librosa.load(path)
    x = librosa.feature.melspectrogram(y=x, sr=sr,n_mels=128,fmax=8000)
    y = librosa.power_to_db(x)
    librosa.display.specshow(y, y_axis='mel', fmax=8000, x_axis='time')
    plt.savefig(f'/content/drive/MyDrive/AlmaBetter/Capstone Projects/Speech Emotion Recognition - Sagar Rokad/train_logmel/fearful/{counter}.png')
  counter=counter+1

# %%
counter=0
for index,path in enumerate(train.path):
  if train.iloc[counter,1]=='happy':
    x, sr = librosa.load(path)
    x = librosa.feature.melspectrogram(y=x, sr=sr,n_mels=128,fmax=8000)
    y = librosa.power_to_db(x)
    librosa.display.specshow(y, y_axis='mel', fmax=8000, x_axis='time')
    plt.savefig(f'/content/drive/MyDrive/AlmaBetter/Capstone Projects/Speech Emotion Recognition - Sagar Rokad/train_logmel/happy/{counter}.png')
  counter=counter+1

# %%
counter=0
for index,path in enumerate(train.path):
  if train.iloc[counter,1]=='neutral':
    x, sr = librosa.load(path)
    x = librosa.feature.melspectrogram(y=x, sr=sr,n_mels=128,fmax=8000)
    y = librosa.power_to_db(x)
    librosa.display.specshow(y, y_axis='mel', fmax=8000, x_axis='time')
    plt.savefig(f'/content/drive/MyDrive/AlmaBetter/Capstone Projects/Speech Emotion Recognition - Sagar Rokad/train_logmel/neutral/{counter}.png')
  counter=counter+1

# %%
counter=0
for index,path in enumerate(train.path):
  if train.iloc[counter,1]=='sad':
    x, sr = librosa.load(path)
    x = librosa.feature.melspectrogram(y=x, sr=sr,n_mels=128,fmax=8000)
    y = librosa.power_to_db(x)
    librosa.display.specshow(y, y_axis='mel', fmax=8000, x_axis='time')
    plt.savefig(f'/content/drive/MyDrive/AlmaBetter/Capstone Projects/Speech Emotion Recognition - Sagar Rokad/train_logmel/sad/{counter}.png')
  counter=counter+1

# %%
counter=0
for index,path in enumerate(train.path):
  if train.iloc[counter,1]=='surprise':
    x, sr = librosa.load(path)
    x = librosa.feature.melspectrogram(y=x, sr=sr,n_mels=128,fmax=8000)
    y = librosa.power_to_db(x)
    librosa.display.specshow(y, y_axis='mel', fmax=8000, x_axis='time')
    plt.savefig(f'/content/drive/MyDrive/AlmaBetter/Capstone Projects/Speech Emotion Recognition - Sagar Rokad/train_logmel/surprised/{counter}.png')
  counter=counter+1

# %% [markdown]
# ### **Making Test_logmel folder**
#
# **Converting testing audio files to spectogram images and storing it in drive**

# %%
counter=0
for index,path in enumerate(test.path):
  if test.iloc[counter,1]=='angry':
    x, sr = librosa.load(path)
    x = librosa.feature.melspectrogram(y=x, sr=sr,n_mels=128,fmax=8000)
    y = librosa.power_to_db(x)
    librosa.display.specshow(y, y_axis='mel', fmax=8000, x_axis='time')
    plt.savefig(f'/content/drive/MyDrive/AlmaBetter/Capstone Projects/Speech Emotion Recognition - Sagar Rokad/test_logmel/angry/{counter}.png')
  counter=counter+1

# %%
counter=0
for index,path in enumerate(test.path):
  if test.iloc[counter,1]=='calm':
    x, sr = librosa.load(path)
    x = librosa.feature.melspectrogram(y=x, sr=sr,n_mels=128,fmax=8000)
    y = librosa.power_to_db(x)
    librosa.display.specshow(y, y_axis='mel', fmax=8000, x_axis='time')
    plt.savefig(f'/content/drive/MyDrive/AlmaBetter/Capstone Projects/Speech Emotion Recognition - Sagar Rokad/test_logmel/calm/{counter}.png')
  counter=counter+1

# %%
counter=0
for index,path in enumerate(test.path):
  if test.iloc[counter,1]=='disgust':
    x, sr = librosa.load(path)
    x = librosa.feature.melspectrogram(y=x, sr=sr,n_mels=128,fmax=8000)
    y = librosa.power_to_db(x)
    librosa.display.specshow(y, y_axis='mel', fmax=8000, x_axis='time')
    plt.savefig(f'/content/drive/MyDrive/AlmaBetter/Capstone Projects/Speech Emotion Recognition - Sagar Rokad/test_logmel/disgust/{counter}.png')
  counter=counter+1

# %%
counter=0
for index,path in enumerate(test.path):
  if test.iloc[counter,1]=='fear':
    x, sr = librosa.load(path)
    x = librosa.feature.melspectrogram(y=x, sr=sr,n_mels=128,fmax=8000)
    y = librosa.power_to_db(x)
    librosa.display.specshow(y, y_axis='mel', fmax=8000, x_axis='time')
    plt.savefig(f'/content/drive/MyDrive/AlmaBetter/Capstone Projects/Speech Emotion Recognition - Sagar Rokad/test_logmel/fearful/{counter}.png')
  counter=counter+1

# %%
counter=0
for index,path in enumerate(test.path):
  if test.iloc[counter,1]=='happy':
    x, sr = librosa.load(path)
    x = librosa.feature.melspectrogram(y=x, sr=sr,n_mels=128,fmax=8000)
    y = librosa.power_to_db(x)
    librosa.display.specshow(y, y_axis='mel', fmax=8000, x_axis='time')
    plt.savefig(f'/content/drive/MyDrive/AlmaBetter/Capstone Projects/Speech Emotion Recognition - Sagar Rokad/test_logmel/happy/{counter}.png')
  counter=counter+1

# %%
counter=0
for index,path in enumerate(test.path):
  if test.iloc[counter,1]=='neutral':
    x, sr = librosa.load(path)
    x = librosa.feature.melspectrogram(y=x, sr=sr,n_mels=128,fmax=8000)
    y = librosa.power_to_db(x)
    librosa.display.specshow(y, y_axis='mel', fmax=8000, x_axis='time')
    plt.savefig(f'/content/drive/MyDrive/AlmaBetter/Capstone Projects/Speech Emotion Recognition - Sagar Rokad/test_logmel/neutral/{counter}.png')
  counter=counter+1

# %%
counter=0
for index,path in enumerate(test.path):
  if test.iloc[counter,1]=='sad':
    x, sr = librosa.load(path)
    x = librosa.feature.melspectrogram(y=x, sr=sr,n_mels=128,fmax=8000)
    y = librosa.power_to_db(x)
    librosa.display.specshow(y, y_axis='mel', fmax=8000, x_axis='time')
    plt.savefig(f'/content/drive/MyDrive/AlmaBetter/Capstone Projects/Speech Emotion Recognition - Sagar Rokad/test_logmel/sad/{counter}.png')
  counter=counter+1

# %%
counter=0
for index,path in enumerate(test.path):
  if test.iloc[counter,1]=='surprise':
    x, sr = librosa.load(path)
    x = librosa.feature.melspectrogram(y=x, sr=sr,n_mels=128,fmax=8000)
    y = librosa.power_to_db(x)
    librosa.display.specshow(y, y_axis='mel', fmax=8000, x_axis='time')
    plt.savefig(f'/content/drive/MyDrive/AlmaBetter/Capstone Projects/Speech Emotion Recognition - Sagar Rokad/test_logmel/surprised/{counter}.png')
  counter=counter+1

# %% [markdown]
# **So here we have converted all the audio files into Mel Spectrogram**
